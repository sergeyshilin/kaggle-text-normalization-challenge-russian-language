# %%
import numpy as np
import pandas as pd

import string
import re
import gc

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
# Out:
# D:\Projects\OCDBot\thirdParty\winpython\python-3.5.4.amd64\Lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
train = pd.read_csv('data/train.csv', encoding='utf-8')
train.dropna(inplace=True)
train = train[train.sentence_id != 492799]

# %%
train['class'].unique()
# Out:
# array(['PLAIN', 'DATE', 'PUNCT', 'ORDINAL', 'VERBATIM', 'LETTERS',
#        'CARDINAL', 'MEASURE', 'TELEPHONE', 'ELECTRONIC', 'DECIMAL',
#        'DIGIT', 'FRACTION', 'MONEY', 'TIME'], dtype=object)

# %%
punctuations = [s[0] for s in train[train['class'] == 'PUNCT']['before'].unique().tolist()]
verbatims = train[train['class'] == 'VERBATIM'].query('after != before').before.unique().tolist()
currencies = [u'¥', u'$', u'€', u'£']
power_signs = [u'²', u'³']
fraction_signs = [u'¼', u'½', u'¾', u'⅔', u'⅓']
specials = list(set(string.punctuation) - set(punctuations) - set(currencies))
date_signs = [u'январ', u'феврал', u'март', u'апрел', u'мая', u'май', u'июн', \
        u'июл', u'август', u'сентябр', u'октябр', u'ноябр', u'декабр', u'год']
quantitatives = [u'тыс', u'млн', u'миллион', u'миллиард', u'млрд', u'трлн', u'триллион']
measure_names = [u'см', u'км', u'%', u'с.', u'метров', u'мин', u'st', u'мм', 
                 u'кило', u'кг', u'м.', u'л.', u'т.', u'ярд', u' м']
currency_names = [u'евро', u'руб', u'долл', u'гривен', u'гривн', u'usd', u'eur', u'юан', u'йен', u'cyp', u'php', u'bsd']

# %%
def is_latin_letter(letter):
    ord_letter = ord(letter)
    return ord_letter >= 97 and ord_letter <= 122

def is_rus_letter(letter):
    ord_letter = ord(letter)
    return ord_letter >= 1072 and ord_letter <= 1105

def is_digit(letter):
    ord_letter = ord(letter)
    return ord_letter >= 48 and ord_letter <= 57

def is_greek(letter):
    ord_letter = ord(letter)
    return ord_letter >= 945 and ord_letter <= 969

def is_dash(letter):
    return letter == u'—'

def is_dot(letter):
    return letter == u'.'

def is_comma(letter):
    return letter == u','

def is_slash(letter):
    return letter == u'/'

def is_colon(letter):
    return letter == u':'

def is_hyphen(letter):
    return letter == u'-'

def is_date_in_word(word):
    for d in date_signs:
        if d in word:
            return True
    return False

def is_measure_in_word(word):
    for m in measure_names:
        if m in word:
            return True
    return False

def is_domain_in_word(word):
    url_pattern = "(([a-zA-Z0-9]+(-[a-zA-Z0-9]+)*\.)+[a-z]{2,10})"
    return len(re.findall(url_pattern, word)) > 0

def is_quantitative_in_word(word):
    for d in quantitatives:
        if d in word:
            return True
    return False

def is_currency_name_in_word(word):
    for c in currency_names:
        if c in word:
            return True
    return False

def generate_features(value):
    
    value = value.strip()
    num_letters = len(value)
    num_words = len(value.split(" "))
    
    rus_letters_num = 0
    en_letters_num = 0
    digits_num = 0
    punctuations_num = 0
    greek_letters_num = 0
    other_letters_num = 0
    special_letters_num = 0
    whitespaces_num = 0
    uppercase_num = 0
    
    has_dash = 0
    has_currency_sign = 0
    has_power_sign = 0
    has_fraction_sign = 0
    has_dot = 0
    has_comma = 0
    has_slash = 0
    has_colon = 0
    num_hyphens = 0

    for l in value:
        if l.isupper():
            uppercase_num += 1
        
        l = l.lower()

        if is_rus_letter(l):
            rus_letters_num += 1
        elif is_latin_letter(l):
            en_letters_num += 1
        elif is_digit(l):
            digits_num += 1
        elif is_greek(l):
            greek_letters_num += 1
        elif is_hyphen(l):
            num_hyphens += 1
        elif l in punctuations:
            punctuations_num += 1
        elif l in specials:
            special_letters_num += 1
        elif l.isspace():
            whitespaces_num += 1
        else:
            other_letters_num += 1
            
        if is_dash(l):
            has_dash = 1
        elif is_dot(l):
            has_dot = 1
        elif is_comma(l):
            has_comma = 1
        elif is_slash(l):
            has_slash = 1
        elif is_colon(l):
            has_colon = 1
        elif l in currencies:
            has_currency_sign = 1
        elif l in power_signs:
            has_power_sign = 1
        elif l in fraction_signs:
            has_fraction_sign = 1

    value = value.lower()
        
    is_uppercase = 1 if num_letters == uppercase_num else 0
    is_single_char = 1 if num_letters == 1 else 0
    is_russian_only = 1 if num_letters == rus_letters_num else 0
    is_english_only = 1 if num_letters == en_letters_num else 0
    is_digits_only = 1 if num_letters == digits_num else 0
    is_punctuation_only = 1 if num_letters == punctuations_num else 0
    is_one_word = 1 if num_words == 1 else 0
    
    has_date = is_date_in_word(value)
    has_measure = is_measure_in_word(value)
    has_domain = is_domain_in_word(value)
    has_quantitative = is_quantitative_in_word(value)
    is_zero_leading = len(value) > 0 and value[0] == u'0'
    has_currency_name = is_currency_name_in_word(value)
    
    return [num_letters, num_words, rus_letters_num, en_letters_num, digits_num, greek_letters_num, \
            other_letters_num, punctuations_num, uppercase_num, special_letters_num, num_hyphens, \
            is_russian_only, is_english_only, is_digits_only, is_punctuation_only, is_one_word, \
            is_uppercase, is_single_char, is_zero_leading, has_dash, has_currency_sign, has_power_sign, \
            has_fraction_sign, has_date, has_dot, has_comma, has_domain, has_quantitative, has_slash, \
            has_currency_name, has_colon, has_measure]

# %%
# %%time
gen_data = train.before.apply(generate_features)
gen_data = np.vstack(gen_data.values)
# Out:
# Wall time: 8min 26s

# %%
# %%time
features_no = len(generate_features(train.before.values[0]))
gen_features = np.zeros((train.shape[0], features_no * 5), dtype = 'int8')

lenghts = train.sentence_id.values
_, lenghts = np.unique(lenghts, return_counts = True)
lenghts = [[count] * count for count in lenghts]
flat_lenghts = [item for sublist in lenghts for item in sublist]
lenghts = np.array(flat_lenghts)

token_ids = train.token_id.values

for index in range(train.shape[0]):
    sentence_length = lenghts[index] - 1
    token_id = token_ids[index]
    
    for offset in range(-2, 3):
        if token_id + offset < 0 or token_id + offset > sentence_length:
            continue
        gen_features[index + offset, ((-offset + 2) * features_no):((-offset + 3) * features_no)] = gen_data[index, :]
# Out:
# Wall time: 3min 30s

# %%
sample_sizes = {
    "PUNCT" : 25000,
    "PLAIN" : 30000,
    "CARDINAL" : 20000,
    "LETTERS" : 20000,
    "DATE" : 20000,
    "ORDINAL" : 15000,
    "MEASURE" : 15000
}

# %%
train.reset_index(inplace=True)

# %%
# %%time
train_data = pd.DataFrame(columns=train.columns)
sample_max_size = 10000

for c in train['class'].unique():
    class_sample = train[train['class'] == c]
    sample_size = sample_sizes[c] if c in sample_sizes else sample_max_size
    if len(class_sample) > sample_max_size:
        train_data = train_data.append(class_sample.sample(sample_size))
    else:
        train_data = train_data.append(class_sample)
# Out:
# Wall time: 21.8 s

# %%
labels = train_data['class'].values
train_indices = train_data.index.values
train_data = np.take(gen_features, train_indices, axis=0)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
train_data = scaler.fit_transform(train_data)
# Out:
# D:\Projects\OCDBot\thirdParty\winpython\python-3.5.4.amd64\Lib\site-packages\sklearn\utils\validation.py:429: DataConversionWarning: Data with input dtype int8 was converted to float64 by StandardScaler.
#   warnings.warn(msg, _DataConversionWarning)

# %%
from sklearn.preprocessing import LabelEncoder

enc = LabelEncoder()
labels = enc.fit_transform(labels)

# %% [markdown]
# ### Train XGBoost classifier

# %%
xtr, xcv, ytr, ycv = train_test_split(train_data, labels, test_size = 0.1,  random_state = 42)

# %%
train = xgb.DMatrix(xtr, label=ytr)
dvalid = xgb.DMatrix(xcv, label=ycv)

# %%
params = [("objective", "multi:softmax"),
          ("num_class", 15),
          ("booster", "gbtree"),
          ("nthread", 3),
          ("eta", 0.01),
          ("max_depth", 8),
          ("subsample", 0.9),
          ("min_child_weight", 1),
          ("colsample_bytree", 0.7),
          ("eval_metric", 'mlogloss'),
          ("eval_metric", 'merror')
         ]
num_rounds = 2000
stop = 40

# %%
watchlist = [(dtrain, 'train'), (dvalid, 'valid')]

# %%
gbm = xgb.train(params, dtrain, num_rounds, evals=watchlist, early_stopping_rounds=stop)
# Out:
# [0]	train-mlogloss:2.63718	train-merror:0.019889	valid-mlogloss:2.63695	valid-merror:0.017357
# Multiple eval metrics have been passed: 'valid-merror' will be used for early stopping.
#
# Will train until valid-merror hasn't improved in 40 rounds.
# [1]	train-mlogloss:2.57272	train-merror:0.013918	valid-mlogloss:2.5724	valid-merror:0.013192
# [2]	train-mlogloss:2.51126	train-merror:0.012839	valid-mlogloss:2.51095	valid-merror:0.011856
# [3]	train-mlogloss:2.45333	train-merror:0.011905	valid-mlogloss:2.45303	valid-merror:0.011109
# [4]	train-mlogloss:2.39862	train-merror:0.012049	valid-mlogloss:2.39833	valid-merror:0.011322
# [5]	train-mlogloss:2.34873	train-merror:0.011937	valid-mlogloss:2.3485	valid-merror:0.011322
# [6]	train-mlogloss:2.29914	train-merror:0.011878	valid-mlogloss:2.2989	valid-merror:0.011376
# [7]	train-mlogloss:2.25245	train-merror:0.011712	valid-mlogloss:2.25222	valid-merror:0.011109
# [8]	train-mlogloss:2.20946	train-merror:0.011477	valid-mlogloss:2.20931	valid-merror:0.010681
# [9]	train-mlogloss:2.16718	train-merror:0.011488	valid-mlogloss:2.16706	valid-merror:0.010575
# [10]	train-mlogloss:2.12799	train-merror:0.01152	valid-mlogloss:2.12792	valid-merror:0.010628
# [11]	train-mlogloss:2.08913	train-merror:0.011301	valid-mlogloss:2.08905	valid-merror:0.010361
# [12]	train-mlogloss:2.05175	train-merror:0.011152	valid-mlogloss:2.05172	valid-merror:0.010254
# [13]	train-mlogloss:2.01575	train-merror:0.01121	valid-mlogloss:2.01564	valid-merror:0.010414
# [14]	train-mlogloss:1.98082	train-merror:0.011173	valid-mlogloss:1.98066	valid-merror:0.010308
# [15]	train-mlogloss:1.94729	train-merror:0.011157	valid-mlogloss:1.94713	valid-merror:0.010628
# [16]	train-mlogloss:1.91451	train-merror:0.011253	valid-mlogloss:1.91441	valid-merror:0.011109
# [17]	train-mlogloss:1.88315	train-merror:0.011141	valid-mlogloss:1.88305	valid-merror:0.010895
# [18]	train-mlogloss:1.85276	train-merror:0.011152	valid-mlogloss:1.85264	valid-merror:0.010949
# [19]	train-mlogloss:1.82377	train-merror:0.011184	valid-mlogloss:1.82372	valid-merror:0.010949
# [20]	train-mlogloss:1.79576	train-merror:0.010986	valid-mlogloss:1.79568	valid-merror:0.010735
# [21]	train-mlogloss:1.76815	train-merror:0.011002	valid-mlogloss:1.76805	valid-merror:0.010788
# [22]	train-mlogloss:1.74137	train-merror:0.010965	valid-mlogloss:1.74128	valid-merror:0.010521
# [23]	train-mlogloss:1.71488	train-merror:0.011018	valid-mlogloss:1.7148	valid-merror:0.010628
# [24]	train-mlogloss:1.68958	train-merror:0.011066	valid-mlogloss:1.68951	valid-merror:0.010628
# [25]	train-mlogloss:1.66455	train-merror:0.010917	valid-mlogloss:1.66448	valid-merror:0.010575
# [26]	train-mlogloss:1.64022	train-merror:0.010901	valid-mlogloss:1.64016	valid-merror:0.010575
# [27]	train-mlogloss:1.61683	train-merror:0.010938	valid-mlogloss:1.61681	valid-merror:0.010681
# [28]	train-mlogloss:1.59397	train-merror:0.010858	valid-mlogloss:1.59395	valid-merror:0.010575
# [29]	train-mlogloss:1.57151	train-merror:0.01081	valid-mlogloss:1.57147	valid-merror:0.010361
# [30]	train-mlogloss:1.54977	train-merror:0.010826	valid-mlogloss:1.54972	valid-merror:0.010414
# [31]	train-mlogloss:1.52844	train-merror:0.010805	valid-mlogloss:1.5284	valid-merror:0.010308
# [32]	train-mlogloss:1.50795	train-merror:0.010778	valid-mlogloss:1.5079	valid-merror:0.010254
# [33]	train-mlogloss:1.48765	train-merror:0.010794	valid-mlogloss:1.4876	valid-merror:0.010254
# [34]	train-mlogloss:1.46776	train-merror:0.010767	valid-mlogloss:1.46771	valid-merror:0.010201
# [35]	train-mlogloss:1.44826	train-merror:0.010756	valid-mlogloss:1.44823	valid-merror:0.010201
# [36]	train-mlogloss:1.42927	train-merror:0.010719	valid-mlogloss:1.42924	valid-merror:0.010201
# [37]	train-mlogloss:1.41123	train-merror:0.010746	valid-mlogloss:1.41121	valid-merror:0.010254
# [38]	train-mlogloss:1.39277	train-merror:0.010687	valid-mlogloss:1.39274	valid-merror:0.010094
# [39]	train-mlogloss:1.37507	train-merror:0.010644	valid-mlogloss:1.37506	valid-merror:0.010147
# [40]	train-mlogloss:1.35763	train-merror:0.010644	valid-mlogloss:1.3576	valid-merror:0.010201
# [41]	train-mlogloss:1.3404	train-merror:0.010634	valid-mlogloss:1.34039	valid-merror:0.010094
# [42]	train-mlogloss:1.32383	train-merror:0.01057	valid-mlogloss:1.3238	valid-merror:0.010094
# [43]	train-mlogloss:1.30727	train-merror:0.010591	valid-mlogloss:1.30724	valid-merror:0.010147
# [44]	train-mlogloss:1.29114	train-merror:0.010543	valid-mlogloss:1.29112	valid-merror:0.010094
# [45]	train-mlogloss:1.27539	train-merror:0.010495	valid-mlogloss:1.27539	valid-merror:0.010094
# [46]	train-mlogloss:1.25971	train-merror:0.010452	valid-mlogloss:1.25972	valid-merror:0.009987
# [47]	train-mlogloss:1.24436	train-merror:0.010404	valid-mlogloss:1.24437	valid-merror:0.009934
# [48]	train-mlogloss:1.22949	train-merror:0.010441	valid-mlogloss:1.22945	valid-merror:0.00988
# [49]	train-mlogloss:1.21461	train-merror:0.010415	valid-mlogloss:1.21458	valid-merror:0.009934
# [50]	train-mlogloss:1.2	train-merror:0.010383	valid-mlogloss:1.19997	valid-merror:0.009934
# [51]	train-mlogloss:1.18602	train-merror:0.010377	valid-mlogloss:1.18597	valid-merror:0.009934
# [52]	train-mlogloss:1.17194	train-merror:0.01034	valid-mlogloss:1.17187	valid-merror:0.009827
# [53]	train-mlogloss:1.15802	train-merror:0.010308	valid-mlogloss:1.15793	valid-merror:0.009827
# [54]	train-mlogloss:1.14453	train-merror:0.010308	valid-mlogloss:1.14443	valid-merror:0.009827
# [55]	train-mlogloss:1.13146	train-merror:0.010308	valid-mlogloss:1.13134	valid-merror:0.00988
# [56]	train-mlogloss:1.11855	train-merror:0.010238	valid-mlogloss:1.11843	valid-merror:0.009774
# [57]	train-mlogloss:1.10566	train-merror:0.010196	valid-mlogloss:1.10554	valid-merror:0.00956
# [58]	train-mlogloss:1.093	train-merror:0.010158	valid-mlogloss:1.09287	valid-merror:0.009507
# [59]	train-mlogloss:1.08053	train-merror:0.010148	valid-mlogloss:1.08042	valid-merror:0.009507
# [60]	train-mlogloss:1.06838	train-merror:0.010148	valid-mlogloss:1.06827	valid-merror:0.009507
# [61]	train-mlogloss:1.05649	train-merror:0.010174	valid-mlogloss:1.05639	valid-merror:0.009613
# [62]	train-mlogloss:1.04472	train-merror:0.010212	valid-mlogloss:1.04462	valid-merror:0.00956
# [63]	train-mlogloss:1.03295	train-merror:0.010153	valid-mlogloss:1.03285	valid-merror:0.009507
# [64]	train-mlogloss:1.02159	train-merror:0.010148	valid-mlogloss:1.02148	valid-merror:0.009453
# [65]	train-mlogloss:1.01018	train-merror:0.010148	valid-mlogloss:1.01006	valid-merror:0.009453
# [66]	train-mlogloss:0.998999	train-merror:0.010105	valid-mlogloss:0.998882	valid-merror:0.0094
# [67]	train-mlogloss:0.987988	train-merror:0.010051	valid-mlogloss:0.987883	valid-merror:0.009186
# [68]	train-mlogloss:0.977267	train-merror:0.010051	valid-mlogloss:0.977161	valid-merror:0.009239
# [69]	train-mlogloss:0.966608	train-merror:0.010019	valid-mlogloss:0.966488	valid-merror:0.009133
# [70]	train-mlogloss:0.956228	train-merror:0.01003	valid-mlogloss:0.956114	valid-merror:0.009186
# [71]	train-mlogloss:0.945853	train-merror:0.01003	valid-mlogloss:0.945725	valid-merror:0.009133
# [72]	train-mlogloss:0.935632	train-merror:0.010003	valid-mlogloss:0.935487	valid-merror:0.009133
# [73]	train-mlogloss:0.925531	train-merror:0.009993	valid-mlogloss:0.925381	valid-merror:0.009133
# [74]	train-mlogloss:0.915596	train-merror:0.009993	valid-mlogloss:0.91543	valid-merror:0.009079
# [75]	train-mlogloss:0.905791	train-merror:0.009961	valid-mlogloss:0.905615	valid-merror:0.009026
# [76]	train-mlogloss:0.896196	train-merror:0.009955	valid-mlogloss:0.896008	valid-merror:0.009026
# [77]	train-mlogloss:0.88675	train-merror:0.009945	valid-mlogloss:0.886554	valid-merror:0.009026
# [78]	train-mlogloss:0.877182	train-merror:0.009955	valid-mlogloss:0.876977	valid-merror:0.009026
# [79]	train-mlogloss:0.86777	train-merror:0.009939	valid-mlogloss:0.867556	valid-merror:0.008866
# [80]	train-mlogloss:0.858741	train-merror:0.009955	valid-mlogloss:0.858521	valid-merror:0.008866
# [81]	train-mlogloss:0.849676	train-merror:0.009934	valid-mlogloss:0.849439	valid-merror:0.008866
# [82]	train-mlogloss:0.840798	train-merror:0.009934	valid-mlogloss:0.840538	valid-merror:0.008866
# [83]	train-mlogloss:0.832098	train-merror:0.009913	valid-mlogloss:0.83185	valid-merror:0.008866
# [84]	train-mlogloss:0.823406	train-merror:0.009918	valid-mlogloss:0.823161	valid-merror:0.008866
# [85]	train-mlogloss:0.814828	train-merror:0.009907	valid-mlogloss:0.814577	valid-merror:0.008812
# [86]	train-mlogloss:0.806355	train-merror:0.009886	valid-mlogloss:0.806086	valid-merror:0.008812
# [87]	train-mlogloss:0.798059	train-merror:0.009886	valid-mlogloss:0.797786	valid-merror:0.008812
# [88]	train-mlogloss:0.789882	train-merror:0.009897	valid-mlogloss:0.789607	valid-merror:0.008919
# [89]	train-mlogloss:0.781631	train-merror:0.009891	valid-mlogloss:0.781351	valid-merror:0.008866
# [90]	train-mlogloss:0.773625	train-merror:0.009875	valid-mlogloss:0.77334	valid-merror:0.008866
# [91]	train-mlogloss:0.765711	train-merror:0.009859	valid-mlogloss:0.765419	valid-merror:0.008866
# [92]	train-mlogloss:0.757846	train-merror:0.009854	valid-mlogloss:0.757547	valid-merror:0.008812
# [93]	train-mlogloss:0.750035	train-merror:0.009854	valid-mlogloss:0.749728	valid-merror:0.008812
# [94]	train-mlogloss:0.742424	train-merror:0.009816	valid-mlogloss:0.742121	valid-merror:0.008759
# [95]	train-mlogloss:0.734909	train-merror:0.009731	valid-mlogloss:0.734594	valid-merror:0.008759
# [96]	train-mlogloss:0.727476	train-merror:0.009742	valid-mlogloss:0.727134	valid-merror:0.008759
# [97]	train-mlogloss:0.720093	train-merror:0.009731	valid-mlogloss:0.719745	valid-merror:0.008759
# [98]	train-mlogloss:0.713024	train-merror:0.009736	valid-mlogloss:0.712683	valid-merror:0.008812
# [99]	train-mlogloss:0.705783	train-merror:0.009731	valid-mlogloss:0.705445	valid-merror:0.008705
# [100]	train-mlogloss:0.698717	train-merror:0.009731	valid-mlogloss:0.698372	valid-merror:0.008759
# [101]	train-mlogloss:0.691679	train-merror:0.009704	valid-mlogloss:0.691325	valid-merror:0.008705
# [102]	train-mlogloss:0.684821	train-merror:0.009683	valid-mlogloss:0.684468	valid-merror:0.008705
# [103]	train-mlogloss:0.677983	train-merror:0.009678	valid-mlogloss:0.677624	valid-merror:0.008705
# [104]	train-mlogloss:0.671426	train-merror:0.009672	valid-mlogloss:0.67106	valid-merror:0.008705
# [105]	train-mlogloss:0.664731	train-merror:0.009683	valid-mlogloss:0.664362	valid-merror:0.008759
# [106]	train-mlogloss:0.658075	train-merror:0.009683	valid-mlogloss:0.657702	valid-merror:0.008759
# [107]	train-mlogloss:0.651497	train-merror:0.009704	valid-mlogloss:0.65112	valid-merror:0.008759
# [108]	train-mlogloss:0.64512	train-merror:0.009704	valid-mlogloss:0.644736	valid-merror:0.008759
# [109]	train-mlogloss:0.638857	train-merror:0.009688	valid-mlogloss:0.638467	valid-merror:0.008705
# [110]	train-mlogloss:0.632571	train-merror:0.009678	valid-mlogloss:0.632176	valid-merror:0.008652
# [111]	train-mlogloss:0.626536	train-merror:0.009624	valid-mlogloss:0.626148	valid-merror:0.008599
# [112]	train-mlogloss:0.620416	train-merror:0.009651	valid-mlogloss:0.620023	valid-merror:0.008652
# [113]	train-mlogloss:0.614325	train-merror:0.009678	valid-mlogloss:0.613921	valid-merror:0.008705
# [114]	train-mlogloss:0.608372	train-merror:0.009672	valid-mlogloss:0.607966	valid-merror:0.008652
# [115]	train-mlogloss:0.602443	train-merror:0.009646	valid-mlogloss:0.602026	valid-merror:0.008599
# [116]	train-mlogloss:0.59649	train-merror:0.009608	valid-mlogloss:0.596071	valid-merror:0.008599
# [117]	train-mlogloss:0.590704	train-merror:0.009592	valid-mlogloss:0.590276	valid-merror:0.008652
# [118]	train-mlogloss:0.585042	train-merror:0.009608	valid-mlogloss:0.584599	valid-merror:0.008652
# [119]	train-mlogloss:0.579325	train-merror:0.009576	valid-mlogloss:0.578869	valid-merror:0.008652
# [120]	train-mlogloss:0.573915	train-merror:0.009603	valid-mlogloss:0.57346	valid-merror:0.008652
# [121]	train-mlogloss:0.568311	train-merror:0.009581	valid-mlogloss:0.567855	valid-merror:0.008599
# [122]	train-mlogloss:0.562878	train-merror:0.009565	valid-mlogloss:0.562417	valid-merror:0.008492
# [123]	train-mlogloss:0.557451	train-merror:0.009555	valid-mlogloss:0.55698	valid-merror:0.008492
# [124]	train-mlogloss:0.552077	train-merror:0.009549	valid-mlogloss:0.551606	valid-merror:0.008492
# [125]	train-mlogloss:0.546786	train-merror:0.009581	valid-mlogloss:0.54631	valid-merror:0.008545
# [126]	train-mlogloss:0.541513	train-merror:0.009571	valid-mlogloss:0.541027	valid-merror:0.008492
# [127]	train-mlogloss:0.536277	train-merror:0.009571	valid-mlogloss:0.535781	valid-merror:0.008492
# [128]	train-mlogloss:0.531165	train-merror:0.009571	valid-mlogloss:0.530662	valid-merror:0.008492
# [129]	train-mlogloss:0.526097	train-merror:0.00956	valid-mlogloss:0.525585	valid-merror:0.008492
# [130]	train-mlogloss:0.521116	train-merror:0.009549	valid-mlogloss:0.520598	valid-merror:0.008492
# [131]	train-mlogloss:0.516106	train-merror:0.009549	valid-mlogloss:0.515584	valid-merror:0.008438
# [132]	train-mlogloss:0.511334	train-merror:0.009544	valid-mlogloss:0.51081	valid-merror:0.008438
# [133]	train-mlogloss:0.50655	train-merror:0.009459	valid-mlogloss:0.506026	valid-merror:0.008332
# [134]	train-mlogloss:0.5018	train-merror:0.009469	valid-mlogloss:0.501269	valid-merror:0.008332
# [135]	train-mlogloss:0.497011	train-merror:0.009469	valid-mlogloss:0.49647	valid-merror:0.008332
# [136]	train-mlogloss:0.492303	train-merror:0.009432	valid-mlogloss:0.491751	valid-merror:0.008332
# [137]	train-mlogloss:0.487683	train-merror:0.009411	valid-mlogloss:0.487125	valid-merror:0.008278
# [138]	train-mlogloss:0.483108	train-merror:0.009427	valid-mlogloss:0.482537	valid-merror:0.008278
# [139]	train-mlogloss:0.478556	train-merror:0.009427	valid-mlogloss:0.477985	valid-merror:0.008278
# [140]	train-mlogloss:0.474078	train-merror:0.009405	valid-mlogloss:0.473504	valid-merror:0.008225
# [141]	train-mlogloss:0.469655	train-merror:0.009416	valid-mlogloss:0.469077	valid-merror:0.008278
# [142]	train-mlogloss:0.465347	train-merror:0.009416	valid-mlogloss:0.46477	valid-merror:0.008278
# [143]	train-mlogloss:0.461021	train-merror:0.009427	valid-mlogloss:0.460431	valid-merror:0.008278
# [144]	train-mlogloss:0.45671	train-merror:0.009389	valid-mlogloss:0.456116	valid-merror:0.008225
# [145]	train-mlogloss:0.452491	train-merror:0.009368	valid-mlogloss:0.451892	valid-merror:0.008225
# [146]	train-mlogloss:0.448317	train-merror:0.009346	valid-mlogloss:0.447714	valid-merror:0.008225
# [147]	train-mlogloss:0.444139	train-merror:0.009341	valid-mlogloss:0.443529	valid-merror:0.008225
# [148]	train-mlogloss:0.440055	train-merror:0.00933	valid-mlogloss:0.439442	valid-merror:0.008225
# [149]	train-mlogloss:0.435929	train-merror:0.00933	valid-mlogloss:0.435322	valid-merror:0.008225
# [150]	train-mlogloss:0.431868	train-merror:0.009357	valid-mlogloss:0.431261	valid-merror:0.008171
# [151]	train-mlogloss:0.427905	train-merror:0.009368	valid-mlogloss:0.427298	valid-merror:0.008171
# [152]	train-mlogloss:0.423984	train-merror:0.00933	valid-mlogloss:0.423369	valid-merror:0.008171
# [153]	train-mlogloss:0.420074	train-merror:0.009346	valid-mlogloss:0.41946	valid-merror:0.008118
# [154]	train-mlogloss:0.416219	train-merror:0.009336	valid-mlogloss:0.415599	valid-merror:0.008118
# [155]	train-mlogloss:0.412398	train-merror:0.00932	valid-mlogloss:0.411773	valid-merror:0.008118
# [156]	train-mlogloss:0.408597	train-merror:0.00932	valid-mlogloss:0.407973	valid-merror:0.008118
# [157]	train-mlogloss:0.404879	train-merror:0.00932	valid-mlogloss:0.404249	valid-merror:0.008118
# [158]	train-mlogloss:0.401119	train-merror:0.009304	valid-mlogloss:0.400488	valid-merror:0.008118
# [159]	train-mlogloss:0.397423	train-merror:0.009282	valid-mlogloss:0.396787	valid-merror:0.008118
# [160]	train-mlogloss:0.393774	train-merror:0.009282	valid-mlogloss:0.393134	valid-merror:0.008118
# [161]	train-mlogloss:0.390166	train-merror:0.009266	valid-mlogloss:0.389514	valid-merror:0.008118
# [162]	train-mlogloss:0.386593	train-merror:0.009224	valid-mlogloss:0.385939	valid-merror:0.008065
# [163]	train-mlogloss:0.383124	train-merror:0.00924	valid-mlogloss:0.382471	valid-merror:0.008065
# [164]	train-mlogloss:0.379634	train-merror:0.009224	valid-mlogloss:0.37898	valid-merror:0.008065
# [165]	train-mlogloss:0.376243	train-merror:0.009218	valid-mlogloss:0.375585	valid-merror:0.008065
# [166]	train-mlogloss:0.372809	train-merror:0.009202	valid-mlogloss:0.372152	valid-merror:0.008065
# [167]	train-mlogloss:0.369437	train-merror:0.009224	valid-mlogloss:0.368782	valid-merror:0.008065
# [168]	train-mlogloss:0.366072	train-merror:0.009224	valid-mlogloss:0.365415	valid-merror:0.008065
# [169]	train-mlogloss:0.362692	train-merror:0.009213	valid-mlogloss:0.362032	valid-merror:0.008118
# [170]	train-mlogloss:0.35941	train-merror:0.009208	valid-mlogloss:0.358749	valid-merror:0.008118
# [171]	train-mlogloss:0.356166	train-merror:0.009181	valid-mlogloss:0.355501	valid-merror:0.008118
# [172]	train-mlogloss:0.352995	train-merror:0.009138	valid-mlogloss:0.352323	valid-merror:0.008118
# [173]	train-mlogloss:0.349791	train-merror:0.009149	valid-mlogloss:0.349123	valid-merror:0.008118
# [174]	train-mlogloss:0.346601	train-merror:0.009154	valid-mlogloss:0.345929	valid-merror:0.008118
# [175]	train-mlogloss:0.343512	train-merror:0.009149	valid-mlogloss:0.342837	valid-merror:0.008118
# [176]	train-mlogloss:0.340444	train-merror:0.009117	valid-mlogloss:0.339767	valid-merror:0.008065
# [177]	train-mlogloss:0.337438	train-merror:0.009106	valid-mlogloss:0.336756	valid-merror:0.008065
# [178]	train-mlogloss:0.3344	train-merror:0.00909	valid-mlogloss:0.333712	valid-merror:0.008065
# [179]	train-mlogloss:0.331446	train-merror:0.009079	valid-mlogloss:0.330751	valid-merror:0.008011
# [180]	train-mlogloss:0.32852	train-merror:0.009079	valid-mlogloss:0.327817	valid-merror:0.008011
# [181]	train-mlogloss:0.325601	train-merror:0.009074	valid-mlogloss:0.324892	valid-merror:0.008011
# [182]	train-mlogloss:0.322727	train-merror:0.009053	valid-mlogloss:0.322021	valid-merror:0.007958
# [183]	train-mlogloss:0.319864	train-merror:0.009063	valid-mlogloss:0.319159	valid-merror:0.007958
# [184]	train-mlogloss:0.317007	train-merror:0.009042	valid-mlogloss:0.316296	valid-merror:0.007958
# [185]	train-mlogloss:0.314211	train-merror:0.009058	valid-mlogloss:0.313498	valid-merror:0.007958
# [186]	train-mlogloss:0.311441	train-merror:0.009058	valid-mlogloss:0.310726	valid-merror:0.007958
# [187]	train-mlogloss:0.308725	train-merror:0.009058	valid-mlogloss:0.308008	valid-merror:0.007958
# [188]	train-mlogloss:0.305988	train-merror:0.009053	valid-mlogloss:0.305267	valid-merror:0.007958
# [189]	train-mlogloss:0.303308	train-merror:0.009063	valid-mlogloss:0.302589	valid-merror:0.007958
# [190]	train-mlogloss:0.300624	train-merror:0.009047	valid-mlogloss:0.299909	valid-merror:0.007958
# [191]	train-mlogloss:0.297995	train-merror:0.009026	valid-mlogloss:0.297276	valid-merror:0.007958
# [192]	train-mlogloss:0.295366	train-merror:0.008978	valid-mlogloss:0.294642	valid-merror:0.007904
# [193]	train-mlogloss:0.292739	train-merror:0.008978	valid-mlogloss:0.292011	valid-merror:0.007904
# [194]	train-mlogloss:0.290203	train-merror:0.008967	valid-mlogloss:0.289473	valid-merror:0.007904
# [195]	train-mlogloss:0.287688	train-merror:0.008967	valid-mlogloss:0.286957	valid-merror:0.007904
# [196]	train-mlogloss:0.285185	train-merror:0.008957	valid-mlogloss:0.284456	valid-merror:0.007904
# [197]	train-mlogloss:0.282662	train-merror:0.008957	valid-mlogloss:0.281936	valid-merror:0.007904
# [198]	train-mlogloss:0.280181	train-merror:0.008935	valid-mlogloss:0.279458	valid-merror:0.007904
# [199]	train-mlogloss:0.277717	train-merror:0.008925	valid-mlogloss:0.276994	valid-merror:0.007904
# [200]	train-mlogloss:0.275298	train-merror:0.008919	valid-mlogloss:0.274568	valid-merror:0.007904
# [201]	train-mlogloss:0.272914	train-merror:0.008919	valid-mlogloss:0.272185	valid-merror:0.007904
# [202]	train-mlogloss:0.270562	train-merror:0.008914	valid-mlogloss:0.269829	valid-merror:0.007904
# [203]	train-mlogloss:0.268285	train-merror:0.008898	valid-mlogloss:0.267553	valid-merror:0.007904
# [204]	train-mlogloss:0.265967	train-merror:0.008893	valid-mlogloss:0.265236	valid-merror:0.007904
# [205]	train-mlogloss:0.263658	train-merror:0.008887	valid-mlogloss:0.262922	valid-merror:0.007904
# [206]	train-mlogloss:0.261354	train-merror:0.008882	valid-mlogloss:0.260617	valid-merror:0.007904
# [207]	train-mlogloss:0.259098	train-merror:0.008876	valid-mlogloss:0.258363	valid-merror:0.007904
# [208]	train-mlogloss:0.256839	train-merror:0.008882	valid-mlogloss:0.2561	valid-merror:0.007904
# [209]	train-mlogloss:0.254649	train-merror:0.008871	valid-mlogloss:0.253906	valid-merror:0.007904
# [210]	train-mlogloss:0.252464	train-merror:0.008866	valid-mlogloss:0.251718	valid-merror:0.007904
# [211]	train-mlogloss:0.250276	train-merror:0.008871	valid-mlogloss:0.249524	valid-merror:0.007904
# [212]	train-mlogloss:0.248144	train-merror:0.00885	valid-mlogloss:0.247389	valid-merror:0.007904
# [213]	train-mlogloss:0.246032	train-merror:0.008855	valid-mlogloss:0.245276	valid-merror:0.007904
# [214]	train-mlogloss:0.243926	train-merror:0.00886	valid-mlogloss:0.243167	valid-merror:0.007904
# [215]	train-mlogloss:0.241866	train-merror:0.008855	valid-mlogloss:0.241104	valid-merror:0.007904
# [216]	train-mlogloss:0.239806	train-merror:0.00885	valid-mlogloss:0.239038	valid-merror:0.007904
# [217]	train-mlogloss:0.237795	train-merror:0.008844	valid-mlogloss:0.237027	valid-merror:0.007904
# [218]	train-mlogloss:0.235778	train-merror:0.008839	valid-mlogloss:0.23501	valid-merror:0.007904
# [219]	train-mlogloss:0.233778	train-merror:0.008834	valid-mlogloss:0.233008	valid-merror:0.007904
# [220]	train-mlogloss:0.231827	train-merror:0.008828	valid-mlogloss:0.23106	valid-merror:0.007904
# [221]	train-mlogloss:0.229878	train-merror:0.008834	valid-mlogloss:0.229112	valid-merror:0.007851
# [222]	train-mlogloss:0.227943	train-merror:0.008823	valid-mlogloss:0.227173	valid-merror:0.007851
# [223]	train-mlogloss:0.226008	train-merror:0.008823	valid-mlogloss:0.225233	valid-merror:0.007851
# [224]	train-mlogloss:0.224128	train-merror:0.008802	valid-mlogloss:0.223353	valid-merror:0.007851
# [225]	train-mlogloss:0.222254	train-merror:0.008786	valid-mlogloss:0.221485	valid-merror:0.007851
# [226]	train-mlogloss:0.220393	train-merror:0.008791	valid-mlogloss:0.219628	valid-merror:0.007851
# [227]	train-mlogloss:0.218516	train-merror:0.008791	valid-mlogloss:0.217746	valid-merror:0.007851
# [228]	train-mlogloss:0.216676	train-merror:0.00878	valid-mlogloss:0.215908	valid-merror:0.007851
# [229]	train-mlogloss:0.214861	train-merror:0.008764	valid-mlogloss:0.214092	valid-merror:0.007851
# [230]	train-mlogloss:0.213082	train-merror:0.008764	valid-mlogloss:0.21231	valid-merror:0.007851
# [231]	train-mlogloss:0.211358	train-merror:0.008759	valid-mlogloss:0.210587	valid-merror:0.007851
# [232]	train-mlogloss:0.209594	train-merror:0.008748	valid-mlogloss:0.208817	valid-merror:0.007851
# [233]	train-mlogloss:0.207865	train-merror:0.008738	valid-mlogloss:0.207085	valid-merror:0.007797
# [234]	train-mlogloss:0.206209	train-merror:0.008727	valid-mlogloss:0.205429	valid-merror:0.007851
# [235]	train-mlogloss:0.204536	train-merror:0.008711	valid-mlogloss:0.203759	valid-merror:0.007797
# [236]	train-mlogloss:0.202866	train-merror:0.008706	valid-mlogloss:0.202084	valid-merror:0.007797
# [237]	train-mlogloss:0.201192	train-merror:0.008711	valid-mlogloss:0.200408	valid-merror:0.007797
# [238]	train-mlogloss:0.1995	train-merror:0.008706	valid-mlogloss:0.198717	valid-merror:0.007797
# [239]	train-mlogloss:0.197898	train-merror:0.0087	valid-mlogloss:0.197114	valid-merror:0.007797
# [240]	train-mlogloss:0.196253	train-merror:0.008695	valid-mlogloss:0.195469	valid-merror:0.007797
# [241]	train-mlogloss:0.194631	train-merror:0.008695	valid-mlogloss:0.19385	valid-merror:0.007797
# [242]	train-mlogloss:0.193052	train-merror:0.008711	valid-mlogloss:0.19227	valid-merror:0.007797
# [243]	train-mlogloss:0.191474	train-merror:0.008668	valid-mlogloss:0.190692	valid-merror:0.007744
# [244]	train-mlogloss:0.189884	train-merror:0.008652	valid-mlogloss:0.189097	valid-merror:0.007744
# [245]	train-mlogloss:0.18837	train-merror:0.008647	valid-mlogloss:0.187581	valid-merror:0.007744
# [246]	train-mlogloss:0.186822	train-merror:0.008642	valid-mlogloss:0.186029	valid-merror:0.007744
# [247]	train-mlogloss:0.185303	train-merror:0.008631	valid-mlogloss:0.184512	valid-merror:0.007744
# [248]	train-mlogloss:0.183806	train-merror:0.008631	valid-mlogloss:0.183011	valid-merror:0.007744
# [249]	train-mlogloss:0.182373	train-merror:0.008631	valid-mlogloss:0.181575	valid-merror:0.007744
# [250]	train-mlogloss:0.180904	train-merror:0.008599	valid-mlogloss:0.180105	valid-merror:0.007691
# [251]	train-mlogloss:0.17946	train-merror:0.008364	valid-mlogloss:0.17866	valid-merror:0.00753
# [252]	train-mlogloss:0.178005	train-merror:0.008358	valid-mlogloss:0.1772	valid-merror:0.00753
# [253]	train-mlogloss:0.176565	train-merror:0.008529	valid-mlogloss:0.175751	valid-merror:0.007691
# [254]	train-mlogloss:0.17511	train-merror:0.008508	valid-mlogloss:0.174302	valid-merror:0.007691
# [255]	train-mlogloss:0.173697	train-merror:0.008476	valid-mlogloss:0.172886	valid-merror:0.007584
# [256]	train-mlogloss:0.172298	train-merror:0.008476	valid-mlogloss:0.17149	valid-merror:0.007584
# [257]	train-mlogloss:0.17092	train-merror:0.008449	valid-mlogloss:0.170111	valid-merror:0.007584
# [258]	train-mlogloss:0.169528	train-merror:0.008417	valid-mlogloss:0.168719	valid-merror:0.007477
# [259]	train-mlogloss:0.168189	train-merror:0.008129	valid-mlogloss:0.167381	valid-merror:0.00721
# [260]	train-mlogloss:0.166834	train-merror:0.008123	valid-mlogloss:0.166029	valid-merror:0.00721
# [261]	train-mlogloss:0.165512	train-merror:0.008102	valid-mlogloss:0.164706	valid-merror:0.00721
# [262]	train-mlogloss:0.164205	train-merror:0.008145	valid-mlogloss:0.163392	valid-merror:0.00721
# [263]	train-mlogloss:0.162897	train-merror:0.008043	valid-mlogloss:0.162084	valid-merror:0.007103
# [264]	train-mlogloss:0.161619	train-merror:0.008033	valid-mlogloss:0.160806	valid-merror:0.007103
# [265]	train-mlogloss:0.160346	train-merror:0.008043	valid-mlogloss:0.159532	valid-merror:0.007157
# [266]	train-mlogloss:0.159097	train-merror:0.008017	valid-mlogloss:0.15828	valid-merror:0.007157
# [267]	train-mlogloss:0.157836	train-merror:0.007995	valid-mlogloss:0.15702	valid-merror:0.007103
# [268]	train-mlogloss:0.156613	train-merror:0.007969	valid-mlogloss:0.155792	valid-merror:0.00705
# [269]	train-mlogloss:0.155378	train-merror:0.007985	valid-mlogloss:0.154556	valid-merror:0.00705
# [270]	train-mlogloss:0.154145	train-merror:0.007963	valid-mlogloss:0.153321	valid-merror:0.00705
# [271]	train-mlogloss:0.152927	train-merror:0.007958	valid-mlogloss:0.152104	valid-merror:0.00705
# [272]	train-mlogloss:0.15174	train-merror:0.007958	valid-mlogloss:0.150916	valid-merror:0.00705
# [273]	train-mlogloss:0.150548	train-merror:0.007958	valid-mlogloss:0.149726	valid-merror:0.00705
# [274]	train-mlogloss:0.149387	train-merror:0.007942	valid-mlogloss:0.148563	valid-merror:0.006996
# [275]	train-mlogloss:0.148232	train-merror:0.007942	valid-mlogloss:0.147408	valid-merror:0.006996
# [276]	train-mlogloss:0.147092	train-merror:0.007937	valid-mlogloss:0.146265	valid-merror:0.006943
# [277]	train-mlogloss:0.145949	train-merror:0.00792	valid-mlogloss:0.145122	valid-merror:0.006943
# [278]	train-mlogloss:0.144839	train-merror:0.007888	valid-mlogloss:0.144012	valid-merror:0.006943
# [279]	train-mlogloss:0.143718	train-merror:0.007888	valid-mlogloss:0.142891	valid-merror:0.006943
# [280]	train-mlogloss:0.142617	train-merror:0.007894	valid-mlogloss:0.14179	valid-merror:0.006943
# [281]	train-mlogloss:0.141496	train-merror:0.007888	valid-mlogloss:0.140671	valid-merror:0.006943
# [282]	train-mlogloss:0.140385	train-merror:0.007851	valid-mlogloss:0.13956	valid-merror:0.006943
# [283]	train-mlogloss:0.139291	train-merror:0.007846	valid-mlogloss:0.138465	valid-merror:0.006943
# [284]	train-mlogloss:0.138218	train-merror:0.007824	valid-mlogloss:0.137395	valid-merror:0.006943
# [285]	train-mlogloss:0.137157	train-merror:0.007824	valid-mlogloss:0.13633	valid-merror:0.006943
# [286]	train-mlogloss:0.136109	train-merror:0.007819	valid-mlogloss:0.13528	valid-merror:0.006943
# [287]	train-mlogloss:0.135056	train-merror:0.007814	valid-mlogloss:0.134231	valid-merror:0.006943
# [288]	train-mlogloss:0.134065	train-merror:0.007819	valid-mlogloss:0.133234	valid-merror:0.006943
# [289]	train-mlogloss:0.133083	train-merror:0.007819	valid-mlogloss:0.132252	valid-merror:0.006943
# [290]	train-mlogloss:0.132091	train-merror:0.007819	valid-mlogloss:0.13126	valid-merror:0.006943
# [291]	train-mlogloss:0.131096	train-merror:0.007814	valid-mlogloss:0.130263	valid-merror:0.006943
# [292]	train-mlogloss:0.130132	train-merror:0.007814	valid-mlogloss:0.129299	valid-merror:0.006943
# [293]	train-mlogloss:0.129171	train-merror:0.007814	valid-mlogloss:0.128334	valid-merror:0.006943
# [294]	train-mlogloss:0.128183	train-merror:0.007808	valid-mlogloss:0.12735	valid-merror:0.006943
# [295]	train-mlogloss:0.127224	train-merror:0.007814	valid-mlogloss:0.126391	valid-merror:0.006943
# [296]	train-mlogloss:0.126259	train-merror:0.007803	valid-mlogloss:0.125419	valid-merror:0.006943
# [297]	train-mlogloss:0.125331	train-merror:0.007792	valid-mlogloss:0.124494	valid-merror:0.006943
# [298]	train-mlogloss:0.124397	train-merror:0.007798	valid-mlogloss:0.123563	valid-merror:0.006943
# [299]	train-mlogloss:0.123508	train-merror:0.007776	valid-mlogloss:0.12267	valid-merror:0.006943
# [300]	train-mlogloss:0.122587	train-merror:0.007782	valid-mlogloss:0.121748	valid-merror:0.006943
# [301]	train-mlogloss:0.12166	train-merror:0.007787	valid-mlogloss:0.120816	valid-merror:0.00689
# [302]	train-mlogloss:0.120761	train-merror:0.007787	valid-mlogloss:0.119914	valid-merror:0.00689
# [303]	train-mlogloss:0.119864	train-merror:0.007792	valid-mlogloss:0.119015	valid-merror:0.00689
# [304]	train-mlogloss:0.118961	train-merror:0.007766	valid-mlogloss:0.118112	valid-merror:0.00689
# [305]	train-mlogloss:0.118077	train-merror:0.00776	valid-mlogloss:0.117226	valid-merror:0.006836
# [306]	train-mlogloss:0.117206	train-merror:0.00775	valid-mlogloss:0.116357	valid-merror:0.006836
# [307]	train-mlogloss:0.116359	train-merror:0.00775	valid-mlogloss:0.115514	valid-merror:0.006836
# [308]	train-mlogloss:0.115527	train-merror:0.00775	valid-mlogloss:0.11468	valid-merror:0.006836
# [309]	train-mlogloss:0.114687	train-merror:0.007744	valid-mlogloss:0.113838	valid-merror:0.006836
# [310]	train-mlogloss:0.113841	train-merror:0.007744	valid-mlogloss:0.112993	valid-merror:0.006836
# [311]	train-mlogloss:0.11301	train-merror:0.007734	valid-mlogloss:0.112164	valid-merror:0.006783
# [312]	train-mlogloss:0.112218	train-merror:0.007744	valid-mlogloss:0.111369	valid-merror:0.006783
# [313]	train-mlogloss:0.111433	train-merror:0.007734	valid-mlogloss:0.110586	valid-merror:0.006783
# [314]	train-mlogloss:0.110617	train-merror:0.007728	valid-mlogloss:0.109769	valid-merror:0.006783
# [315]	train-mlogloss:0.109829	train-merror:0.007707	valid-mlogloss:0.108976	valid-merror:0.006783
# [316]	train-mlogloss:0.109021	train-merror:0.007702	valid-mlogloss:0.108163	valid-merror:0.006783
# [317]	train-mlogloss:0.108236	train-merror:0.007707	valid-mlogloss:0.107378	valid-merror:0.006783
# [318]	train-mlogloss:0.107487	train-merror:0.007702	valid-mlogloss:0.106628	valid-merror:0.006783
# [319]	train-mlogloss:0.106722	train-merror:0.007702	valid-mlogloss:0.105857	valid-merror:0.006783
# [320]	train-mlogloss:0.105967	train-merror:0.007702	valid-mlogloss:0.105101	valid-merror:0.006783
# [321]	train-mlogloss:0.105196	train-merror:0.007696	valid-mlogloss:0.10433	valid-merror:0.006783
# [322]	train-mlogloss:0.104472	train-merror:0.007696	valid-mlogloss:0.103606	valid-merror:0.006783
# [323]	train-mlogloss:0.103731	train-merror:0.007696	valid-mlogloss:0.102863	valid-merror:0.006783
# [324]	train-mlogloss:0.10299	train-merror:0.007696	valid-mlogloss:0.102125	valid-merror:0.006783
# [325]	train-mlogloss:0.102266	train-merror:0.007691	valid-mlogloss:0.101399	valid-merror:0.006783
# [326]	train-mlogloss:0.101546	train-merror:0.007669	valid-mlogloss:0.100671	valid-merror:0.006783
# [327]	train-mlogloss:0.100837	train-merror:0.007637	valid-mlogloss:0.099966	valid-merror:0.006729
# [328]	train-mlogloss:0.100151	train-merror:0.007637	valid-mlogloss:0.099284	valid-merror:0.006729
# [329]	train-mlogloss:0.09944	train-merror:0.007621	valid-mlogloss:0.098575	valid-merror:0.006729
# [330]	train-mlogloss:0.09878	train-merror:0.007627	valid-mlogloss:0.097915	valid-merror:0.006729
# [331]	train-mlogloss:0.098103	train-merror:0.007616	valid-mlogloss:0.097237	valid-merror:0.006729
# [332]	train-mlogloss:0.097428	train-merror:0.007611	valid-mlogloss:0.096565	valid-merror:0.006729
# [333]	train-mlogloss:0.096757	train-merror:0.007605	valid-mlogloss:0.095896	valid-merror:0.006729
# [334]	train-mlogloss:0.096092	train-merror:0.007605	valid-mlogloss:0.09523	valid-merror:0.006729
# [335]	train-mlogloss:0.095436	train-merror:0.007595	valid-mlogloss:0.094577	valid-merror:0.006729
# [336]	train-mlogloss:0.094782	train-merror:0.007589	valid-mlogloss:0.09392	valid-merror:0.006729
# [337]	train-mlogloss:0.094137	train-merror:0.007595	valid-mlogloss:0.093274	valid-merror:0.006729
# [338]	train-mlogloss:0.093488	train-merror:0.007589	valid-mlogloss:0.092623	valid-merror:0.006729
# [339]	train-mlogloss:0.092858	train-merror:0.007579	valid-mlogloss:0.091997	valid-merror:0.006729
# [340]	train-mlogloss:0.092231	train-merror:0.007579	valid-mlogloss:0.091369	valid-merror:0.006729
# [341]	train-mlogloss:0.091603	train-merror:0.007579	valid-mlogloss:0.090736	valid-merror:0.006729
# [342]	train-mlogloss:0.090985	train-merror:0.007563	valid-mlogloss:0.090115	valid-merror:0.006729
# [343]	train-mlogloss:0.09038	train-merror:0.007563	valid-mlogloss:0.089511	valid-merror:0.006729
# [344]	train-mlogloss:0.089776	train-merror:0.007568	valid-mlogloss:0.088905	valid-merror:0.006729
# [345]	train-mlogloss:0.089192	train-merror:0.007568	valid-mlogloss:0.088319	valid-merror:0.006729
# [346]	train-mlogloss:0.088595	train-merror:0.007568	valid-mlogloss:0.087718	valid-merror:0.006729
# [347]	train-mlogloss:0.088026	train-merror:0.007579	valid-mlogloss:0.087151	valid-merror:0.006729
# [348]	train-mlogloss:0.087453	train-merror:0.007573	valid-mlogloss:0.08658	valid-merror:0.006676
# [349]	train-mlogloss:0.086883	train-merror:0.007568	valid-mlogloss:0.08601	valid-merror:0.006676
# [350]	train-mlogloss:0.086308	train-merror:0.007557	valid-mlogloss:0.085438	valid-merror:0.006676
# [351]	train-mlogloss:0.085742	train-merror:0.007557	valid-mlogloss:0.084875	valid-merror:0.006676
# [352]	train-mlogloss:0.085166	train-merror:0.007552	valid-mlogloss:0.0843	valid-merror:0.006676
# [353]	train-mlogloss:0.084612	train-merror:0.007547	valid-mlogloss:0.083749	valid-merror:0.006676
# [354]	train-mlogloss:0.084066	train-merror:0.007541	valid-mlogloss:0.083203	valid-merror:0.006676
# [355]	train-mlogloss:0.083533	train-merror:0.007541	valid-mlogloss:0.082669	valid-merror:0.006623
# [356]	train-mlogloss:0.083003	train-merror:0.007541	valid-mlogloss:0.082136	valid-merror:0.006623
# [357]	train-mlogloss:0.082461	train-merror:0.007536	valid-mlogloss:0.081592	valid-merror:0.006623
# [358]	train-mlogloss:0.08193	train-merror:0.007536	valid-mlogloss:0.081061	valid-merror:0.006623
# [359]	train-mlogloss:0.081414	train-merror:0.007531	valid-mlogloss:0.080543	valid-merror:0.006623
# [360]	train-mlogloss:0.080894	train-merror:0.007531	valid-mlogloss:0.080027	valid-merror:0.006623
# [361]	train-mlogloss:0.08038	train-merror:0.007525	valid-mlogloss:0.079512	valid-merror:0.006623
# [362]	train-mlogloss:0.079878	train-merror:0.007531	valid-mlogloss:0.079009	valid-merror:0.006623
# [363]	train-mlogloss:0.079373	train-merror:0.007515	valid-mlogloss:0.078505	valid-merror:0.006623
# [364]	train-mlogloss:0.078871	train-merror:0.00752	valid-mlogloss:0.078001	valid-merror:0.006623
# [365]	train-mlogloss:0.078397	train-merror:0.00752	valid-mlogloss:0.077527	valid-merror:0.006623
# [366]	train-mlogloss:0.077919	train-merror:0.00752	valid-mlogloss:0.077044	valid-merror:0.006623
# [367]	train-mlogloss:0.077425	train-merror:0.007515	valid-mlogloss:0.076551	valid-merror:0.006569
# [368]	train-mlogloss:0.076951	train-merror:0.007515	valid-mlogloss:0.076075	valid-merror:0.006569
# [369]	train-mlogloss:0.076487	train-merror:0.007509	valid-mlogloss:0.075609	valid-merror:0.006569
# [370]	train-mlogloss:0.076003	train-merror:0.007461	valid-mlogloss:0.075129	valid-merror:0.006569
# [371]	train-mlogloss:0.07554	train-merror:0.007461	valid-mlogloss:0.074664	valid-merror:0.006569
# [372]	train-mlogloss:0.075079	train-merror:0.007456	valid-mlogloss:0.074205	valid-merror:0.006569
# [373]	train-mlogloss:0.074629	train-merror:0.007456	valid-mlogloss:0.073756	valid-merror:0.006569
# [374]	train-mlogloss:0.074188	train-merror:0.007456	valid-mlogloss:0.073314	valid-merror:0.006569
# [375]	train-mlogloss:0.073732	train-merror:0.007456	valid-mlogloss:0.072859	valid-merror:0.006569
# [376]	train-mlogloss:0.073282	train-merror:0.007456	valid-mlogloss:0.072406	valid-merror:0.006569
# [377]	train-mlogloss:0.072836	train-merror:0.007445	valid-mlogloss:0.071962	valid-merror:0.006569
# [378]	train-mlogloss:0.072401	train-merror:0.007445	valid-mlogloss:0.071527	valid-merror:0.006569
# [379]	train-mlogloss:0.071969	train-merror:0.007445	valid-mlogloss:0.071096	valid-merror:0.006569
# [380]	train-mlogloss:0.071544	train-merror:0.007445	valid-mlogloss:0.070668	valid-merror:0.006569
# [381]	train-mlogloss:0.071117	train-merror:0.007445	valid-mlogloss:0.070243	valid-merror:0.006569
# [382]	train-mlogloss:0.070691	train-merror:0.00744	valid-mlogloss:0.069817	valid-merror:0.006569
# [383]	train-mlogloss:0.070272	train-merror:0.007402	valid-mlogloss:0.069393	valid-merror:0.006569
# [384]	train-mlogloss:0.069852	train-merror:0.007397	valid-mlogloss:0.068972	valid-merror:0.006569
# [385]	train-mlogloss:0.06944	train-merror:0.007392	valid-mlogloss:0.068563	valid-merror:0.006569
# [386]	train-mlogloss:0.069038	train-merror:0.007392	valid-mlogloss:0.068163	valid-merror:0.006569
# [387]	train-mlogloss:0.068625	train-merror:0.007386	valid-mlogloss:0.067751	valid-merror:0.006569
# [388]	train-mlogloss:0.068223	train-merror:0.007381	valid-mlogloss:0.067348	valid-merror:0.006569
# [389]	train-mlogloss:0.067821	train-merror:0.00737	valid-mlogloss:0.066948	valid-merror:0.006569
# [390]	train-mlogloss:0.067432	train-merror:0.00737	valid-mlogloss:0.066559	valid-merror:0.006569
# [391]	train-mlogloss:0.067041	train-merror:0.007365	valid-mlogloss:0.06617	valid-merror:0.006569
# [392]	train-mlogloss:0.066656	train-merror:0.007354	valid-mlogloss:0.065785	valid-merror:0.006569
# [393]	train-mlogloss:0.06627	train-merror:0.007349	valid-mlogloss:0.065402	valid-merror:0.006516
# [394]	train-mlogloss:0.065893	train-merror:0.007344	valid-mlogloss:0.065023	valid-merror:0.006516
# [395]	train-mlogloss:0.06552	train-merror:0.007333	valid-mlogloss:0.064651	valid-merror:0.006516
# [396]	train-mlogloss:0.065154	train-merror:0.007333	valid-mlogloss:0.064286	valid-merror:0.006516
# [397]	train-mlogloss:0.064785	train-merror:0.007317	valid-mlogloss:0.063916	valid-merror:0.006516
# [398]	train-mlogloss:0.064413	train-merror:0.007301	valid-mlogloss:0.063546	valid-merror:0.006516
# [399]	train-mlogloss:0.064044	train-merror:0.00729	valid-mlogloss:0.063178	valid-merror:0.006462
# [400]	train-mlogloss:0.063691	train-merror:0.007306	valid-mlogloss:0.062825	valid-merror:0.006462
# [401]	train-mlogloss:0.063327	train-merror:0.007306	valid-mlogloss:0.062461	valid-merror:0.006462
# [402]	train-mlogloss:0.062965	train-merror:0.007296	valid-mlogloss:0.0621	valid-merror:0.006462
# [403]	train-mlogloss:0.062617	train-merror:0.00728	valid-mlogloss:0.061753	valid-merror:0.006462
# [404]	train-mlogloss:0.062274	train-merror:0.007274	valid-mlogloss:0.061408	valid-merror:0.006462
# [405]	train-mlogloss:0.061929	train-merror:0.007274	valid-mlogloss:0.06106	valid-merror:0.006462
# [406]	train-mlogloss:0.061584	train-merror:0.007274	valid-mlogloss:0.060715	valid-merror:0.006462
# [407]	train-mlogloss:0.061241	train-merror:0.007274	valid-mlogloss:0.060375	valid-merror:0.006462
# [408]	train-mlogloss:0.060922	train-merror:0.007264	valid-mlogloss:0.060057	valid-merror:0.006462
# [409]	train-mlogloss:0.060586	train-merror:0.007264	valid-mlogloss:0.059723	valid-merror:0.006462
# [410]	train-mlogloss:0.060278	train-merror:0.007264	valid-mlogloss:0.059414	valid-merror:0.006462
# [411]	train-mlogloss:0.059954	train-merror:0.007264	valid-mlogloss:0.059088	valid-merror:0.006462
# [412]	train-mlogloss:0.059634	train-merror:0.007248	valid-mlogloss:0.058769	valid-merror:0.006462
# [413]	train-mlogloss:0.059314	train-merror:0.007248	valid-mlogloss:0.05845	valid-merror:0.006462
# [414]	train-mlogloss:0.058994	train-merror:0.007248	valid-mlogloss:0.058129	valid-merror:0.006462
# [415]	train-mlogloss:0.058669	train-merror:0.007248	valid-mlogloss:0.057807	valid-merror:0.006462
# [416]	train-mlogloss:0.058365	train-merror:0.007248	valid-mlogloss:0.057503	valid-merror:0.006462
# [417]	train-mlogloss:0.058055	train-merror:0.007248	valid-mlogloss:0.05719	valid-merror:0.006462
# [418]	train-mlogloss:0.05776	train-merror:0.007248	valid-mlogloss:0.056897	valid-merror:0.006462
# [419]	train-mlogloss:0.057462	train-merror:0.007248	valid-mlogloss:0.056596	valid-merror:0.006462
# [420]	train-mlogloss:0.057152	train-merror:0.007242	valid-mlogloss:0.056288	valid-merror:0.006462
# [421]	train-mlogloss:0.056857	train-merror:0.007237	valid-mlogloss:0.055994	valid-merror:0.006462
# [422]	train-mlogloss:0.056563	train-merror:0.007226	valid-mlogloss:0.055702	valid-merror:0.006409
# [423]	train-mlogloss:0.056287	train-merror:0.007226	valid-mlogloss:0.055426	valid-merror:0.006409
# [424]	train-mlogloss:0.055984	train-merror:0.007221	valid-mlogloss:0.055126	valid-merror:0.006409
# [425]	train-mlogloss:0.055703	train-merror:0.007215	valid-mlogloss:0.054849	valid-merror:0.006409
# [426]	train-mlogloss:0.055417	train-merror:0.007215	valid-mlogloss:0.054563	valid-merror:0.006409
# [427]	train-mlogloss:0.055136	train-merror:0.007215	valid-mlogloss:0.054286	valid-merror:0.006409
# [428]	train-mlogloss:0.054861	train-merror:0.007205	valid-mlogloss:0.054011	valid-merror:0.006355
# [429]	train-mlogloss:0.054569	train-merror:0.007189	valid-mlogloss:0.05372	valid-merror:0.006302
# [430]	train-mlogloss:0.054302	train-merror:0.007189	valid-mlogloss:0.053456	valid-merror:0.006302
# [431]	train-mlogloss:0.054034	train-merror:0.007194	valid-mlogloss:0.053188	valid-merror:0.006302
# [432]	train-mlogloss:0.053771	train-merror:0.007194	valid-mlogloss:0.052925	valid-merror:0.006302
# [433]	train-mlogloss:0.053506	train-merror:0.007194	valid-mlogloss:0.052662	valid-merror:0.006302
# [434]	train-mlogloss:0.053224	train-merror:0.007194	valid-mlogloss:0.052383	valid-merror:0.006302
# [435]	train-mlogloss:0.052974	train-merror:0.007183	valid-mlogloss:0.052133	valid-merror:0.006302
# [436]	train-mlogloss:0.052713	train-merror:0.007183	valid-mlogloss:0.051874	valid-merror:0.006302
# [437]	train-mlogloss:0.052459	train-merror:0.007183	valid-mlogloss:0.051621	valid-merror:0.006302
# [438]	train-mlogloss:0.052201	train-merror:0.007183	valid-mlogloss:0.051365	valid-merror:0.006302
# [439]	train-mlogloss:0.05195	train-merror:0.007173	valid-mlogloss:0.051115	valid-merror:0.006302
# [440]	train-mlogloss:0.051695	train-merror:0.007173	valid-mlogloss:0.050865	valid-merror:0.006302
# [441]	train-mlogloss:0.05145	train-merror:0.007173	valid-mlogloss:0.050621	valid-merror:0.006302
# [442]	train-mlogloss:0.051204	train-merror:0.007167	valid-mlogloss:0.050374	valid-merror:0.006302
# [443]	train-mlogloss:0.050967	train-merror:0.007167	valid-mlogloss:0.050136	valid-merror:0.006302
# [444]	train-mlogloss:0.050723	train-merror:0.007167	valid-mlogloss:0.049891	valid-merror:0.006302
# [445]	train-mlogloss:0.05048	train-merror:0.007167	valid-mlogloss:0.049648	valid-merror:0.006302
# [446]	train-mlogloss:0.050246	train-merror:0.007162	valid-mlogloss:0.049416	valid-merror:0.006302
# [447]	train-mlogloss:0.050005	train-merror:0.007157	valid-mlogloss:0.049175	valid-merror:0.006302
# [448]	train-mlogloss:0.049779	train-merror:0.007157	valid-mlogloss:0.048949	valid-merror:0.006302
# [449]	train-mlogloss:0.049542	train-merror:0.007157	valid-mlogloss:0.048712	valid-merror:0.006302
# [450]	train-mlogloss:0.049309	train-merror:0.007151	valid-mlogloss:0.048477	valid-merror:0.006302
# [451]	train-mlogloss:0.049081	train-merror:0.007151	valid-mlogloss:0.04825	valid-merror:0.006302
# [452]	train-mlogloss:0.048856	train-merror:0.007146	valid-mlogloss:0.048023	valid-merror:0.006302
# [453]	train-mlogloss:0.04863	train-merror:0.007146	valid-mlogloss:0.047796	valid-merror:0.006302
# [454]	train-mlogloss:0.048409	train-merror:0.007141	valid-mlogloss:0.047576	valid-merror:0.006302
# [455]	train-mlogloss:0.048185	train-merror:0.007141	valid-mlogloss:0.047354	valid-merror:0.006302
# [456]	train-mlogloss:0.047963	train-merror:0.007135	valid-mlogloss:0.047134	valid-merror:0.006302
# [457]	train-mlogloss:0.047748	train-merror:0.007135	valid-mlogloss:0.046921	valid-merror:0.006302
# [458]	train-mlogloss:0.04753	train-merror:0.00713	valid-mlogloss:0.046707	valid-merror:0.006302
# [459]	train-mlogloss:0.047317	train-merror:0.007114	valid-mlogloss:0.046492	valid-merror:0.006302
# [460]	train-mlogloss:0.047107	train-merror:0.007119	valid-mlogloss:0.046281	valid-merror:0.006302
# [461]	train-mlogloss:0.0469	train-merror:0.007125	valid-mlogloss:0.046077	valid-merror:0.006302
# [462]	train-mlogloss:0.046702	train-merror:0.007119	valid-mlogloss:0.045881	valid-merror:0.006302
# [463]	train-mlogloss:0.046494	train-merror:0.007119	valid-mlogloss:0.04567	valid-merror:0.006302
# [464]	train-mlogloss:0.04629	train-merror:0.007119	valid-mlogloss:0.045469	valid-merror:0.006302
# [465]	train-mlogloss:0.046088	train-merror:0.007119	valid-mlogloss:0.045265	valid-merror:0.006302
# [466]	train-mlogloss:0.045884	train-merror:0.007119	valid-mlogloss:0.045063	valid-merror:0.006302
# [467]	train-mlogloss:0.045684	train-merror:0.007119	valid-mlogloss:0.044862	valid-merror:0.006302
# [468]	train-mlogloss:0.045491	train-merror:0.007109	valid-mlogloss:0.04467	valid-merror:0.006302
# [469]	train-mlogloss:0.045295	train-merror:0.007109	valid-mlogloss:0.044475	valid-merror:0.006302
# Stopping. Best iteration:
# [429]	train-mlogloss:0.054569	train-merror:0.007189	valid-mlogloss:0.05372	valid-merror:0.006302

# %%
gbm.save_model('xgboost_32fwc.model')

# %%
(dtrain.num_row() * 0.007189 + dvalid.num_row() * 0.006302)
# Out:
# 1464.038252

# %%
gc.collect()

# %% [markdown]
# #### Predict and validate

# %%
test_data = scaler.transform(gen_features)
test_labels = enc.transform(train['class'].values)
# Out:
# D:\Projects\OCDBot\thirdParty\winpython\python-3.5.4.amd64\Lib\site-packages\sklearn\utils\validation.py:429: DataConversionWarning: Data with input dtype int8 was converted to float64 by StandardScaler.
#   warnings.warn(msg, _DataConversionWarning)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-127-ae2040706965> in <module>()
# ----> 1 test_data = scaler.transform(gen_features)
#       2 test_labels = enc.transform(train['class'].values)
#
# D:\Projects\OCDBot\thirdParty\winpython\python-3.5.4.amd64\Lib\site-packages\sklearn\preprocessing\data.py in transform(self, X, y, copy)
#     658         else:
#     659             if self.with_mean:
# --> 660                 X -= self.mean_
#     661             if self.with_std:
#     662                 X /= self.scale_
#
# KeyboardInterrupt:

# %%
dtest = xgb.DMatrix(test_data, label=test_labels)

# %%
predictions = gbm.predict(dtest)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(predictions, test_labels)
# Out:
# 0.99012823394692573

# %%
np.sum(predictions != test_labels)
# Out:
# 104389

# %%
train['predicted_class'] = np.apply_along_axis((lambda x: enc.classes_[x]), 0, predictions.astype(np.uint8))

# %%
prediction_errors = train[train['class'] != train['predicted_class']]['class'].value_counts()

# %%
for i in range(len(prediction_errors)):
    print ("{:>16}{:>12.2f}%".format(prediction_errors.index[i], prediction_errors[i] * 100 / len(train[train['class'] == prediction_errors.index[i]])))
# Out:
#            PLAIN        0.70%
#          LETTERS       11.19%
#          ORDINAL       41.32%
#         CARDINAL        4.10%
#             DATE        0.32%
#          MEASURE        1.13%
#        TELEPHONE        0.97%
#            PUNCT        0.00%
#            MONEY        1.15%
#       ELECTRONIC        0.26%
#          DECIMAL        0.21%
#             TIME        0.62%
#         VERBATIM        0.00%

# %%
prediction_errors
# Out:
# PLAIN         51379
# LETTERS       21211
# ORDINAL       19313
# CARDINAL      11175
# DATE            586
# MEASURE         458
# TELEPHONE        98
# PUNCT            91
# MONEY            31
# ELECTRONIC       15
# DECIMAL          15
# TIME             12
# VERBATIM          5
# Name: class, dtype: int64

# %%
for c in train['class'].unique():
    print ("Errors for class {}:".format(c))
    print (train[(train['class'] == c) & (train['class'] != train['predicted_class'])]['predicted_class'].value_counts())
    print ("\n" * 2)
# Out:
# Errors for class PLAIN:
# LETTERS       25168
# ORDINAL       13232
# PUNCT          6965
# VERBATIM       5935
# ELECTRONIC       79
# Name: predicted_class, dtype: int64
#
#
#
# Errors for class DATE:
# MEASURE       388
# TELEPHONE     124
# ORDINAL        43
# FRACTION       28
# ELECTRONIC      3
# Name: predicted_class, dtype: int64
#
#
#
# Errors for class PUNCT:
# TELEPHONE    91
# Name: predicted_class, dtype: int64
#
#
#
# Errors for class ORDINAL:
# CARDINAL    12242
# LETTERS      7058
# MEASURE         8
# PLAIN           5
# Name: predicted_class, dtype: int64
#
#
#
# Errors for class VERBATIM:
# PLAIN    5
# Name: predicted_class, dtype: int64
#
#
#
# Errors for class LETTERS:
# PLAIN         21199
# ELECTRONIC       12
# Name: predicted_class, dtype: int64
#
#
#
# Errors for class CARDINAL:
# LETTERS      7608
# ORDINAL      2977
# DECIMAL       259
# TELEPHONE     246
# PLAIN          80
# DIGIT           5
# Name: predicted_class, dtype: int64
#
#
#
# Errors for class MEASURE:
# DATE          231
# MONEY          81
# DECIMAL        80
# ORDINAL        53
# LETTERS         7
# FRACTION        5
# ELECTRONIC      1
# Name: predicted_class, dtype: int64
#
#
#
# Errors for class TELEPHONE:
# CARDINAL    54
# ORDINAL     15
# DATE        12
# MEASURE      9
# DECIMAL      6
# MONEY        2
# Name: predicted_class, dtype: int64
#
#
#
# Errors for class ELECTRONIC:
# PLAIN    10
# DATE      4
# TIME      1
# Name: predicted_class, dtype: int64
#
#
#
# Errors for class DECIMAL:
# MEASURE    13
# MONEY       2
# Name: predicted_class, dtype: int64
#
#
#
# Errors for class DIGIT:
# Series([], Name: predicted_class, dtype: int64)
#
#
#
# Errors for class FRACTION:
# Series([], Name: predicted_class, dtype: int64)
#
#
#
# Errors for class MONEY:
# MEASURE       18
# LETTERS        7
# DECIMAL        3
# ELECTRONIC     2
# TELEPHONE      1
# Name: predicted_class, dtype: int64
#
#
#
# Errors for class TIME:
# LETTERS       9
# ELECTRONIC    2
# MEASURE       1
# Name: predicted_class, dtype: int64
